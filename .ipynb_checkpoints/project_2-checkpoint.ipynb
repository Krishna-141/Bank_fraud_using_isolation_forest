# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import RobustScaler

# %%
raw_data = pd.read_csv('bank_transactions_data_2.csv')
raw_data.head()
# Out:
#   TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0      TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1      TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2      TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3      TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4      TX000005   AC00411              13.45  2023-10-16 17:51:24
#
#   TransactionType   Location DeviceID      IP Address MerchantID Channel  \
# 0           Debit  San Diego  D000380  162.198.218.92       M015     ATM
# 1           Debit    Houston  D000051     13.149.61.4       M052     ATM
# 2           Debit       Mesa  D000235  215.97.143.157       M009  Online
# 3           Debit    Raleigh  D000187  200.13.225.150       M002  Online
# 4          Credit    Atlanta  D000308    65.164.3.100       M091  Online
#
#    CustomerAge CustomerOccupation  TransactionDuration  LoginAttempts  \
# 0           70             Doctor                   81              1
# 1           68             Doctor                  141              1
# 2           19            Student                   56              1
# 3           26            Student                   25              1
# 4           26            Student                  198              1
#
#    AccountBalance PreviousTransactionDate
# 0         5112.21     2024-11-04 08:08:08
# 1        13758.91     2024-11-04 08:09:35
# 2         1122.35     2024-11-04 08:07:04
# 3         8569.06     2024-11-04 08:09:06
# 4         7429.40     2024-11-04 08:06:39

# %%
raw_data.isnull().sum()
# Out:
# TransactionID              0
# AccountID                  0
# TransactionAmount          0
# TransactionDate            0
# TransactionType            0
# Location                   0
# DeviceID                   0
# IP Address                 0
# MerchantID                 0
# Channel                    0
# CustomerAge                0
# CustomerOccupation         0
# TransactionDuration        0
# LoginAttempts              0
# AccountBalance             0
# PreviousTransactionDate    0
# dtype: int64

# %%
data = raw_data.copy()
data = data.drop(['MerchantID','IP Address','DeviceID'],axis=1)

# %%
# 1. Transaction Frequency
transaction_frequency = data.groupby('AccountID')['TransactionID'].count().reset_index()
transaction_frequency.columns = ['AccountID', 'TransactionFrequency']
data = data.merge(transaction_frequency, on='AccountID', how='left')

# 2. Time Features
data['TransactionDate'] = pd.to_datetime(data['TransactionDate'])
data['TransactionHour'] = data['TransactionDate'].dt.hour
data['TransactionDay'] = data['TransactionDate'].dt.day
data['TransactionMonth'] = data['TransactionDate'].dt.month

# 3. Velocity Features
data = data.sort_values(by=['AccountID', 'TransactionDate'])
data['TransactionTimeDiff'] = data.groupby('AccountID')['TransactionDate'].diff().dt.total_seconds()
data['TransactionTimeDiff'] = data['TransactionTimeDiff'].fillna(0)

# Display the dataset with new features
data.head()
# Out:
#      TransactionID AccountID  TransactionAmount     TransactionDate  \
# 1312      TX001313   AC00001              47.79 2023-09-15 17:00:20
# 2016      TX002017   AC00001             212.97 2023-11-14 16:56:34
# 2120      TX002121   AC00002             476.99 2023-01-10 16:00:32
# 20        TX000021   AC00002              59.32 2023-02-28 16:36:58
# 1476      TX001477   AC00002              12.62 2023-05-05 16:35:44
#
#      TransactionType     Location Channel  CustomerAge CustomerOccupation  \
# 1312           Debit       Denver  Branch           25            Student
# 2016           Debit      Atlanta  Online           59           Engineer
# 2120           Debit    San Diego  Online           23            Student
# 20             Debit  Los Angeles  Branch           71            Retired
# 1476           Debit      El Paso  Branch           33             Doctor
#
#       TransactionDuration  LoginAttempts  AccountBalance  \
# 1312                   37              1         1649.92
# 2016                  178              1         4180.40
# 2120                  187              1         1154.48
# 20                     38              1         5750.89
# 1476                   61              1         6420.47
#
#      PreviousTransactionDate  TransactionFrequency  TransactionHour  \
# 1312     2024-11-04 08:11:55                     2               17
# 2016     2024-11-04 08:10:42                     2               16
# 2120     2024-11-04 08:10:10                     7               16
# 20       2024-11-04 08:09:24                     7               16
# 1476     2024-11-04 08:09:03                     7               16
#
#       TransactionDay  TransactionMonth  TransactionTimeDiff
# 1312              15                 9                  0.0
# 2016              14                11            5183774.0
# 2120              10                 1                  0.0
# 20                28                 2            4235786.0
# 1476               5                 5            5702326.0

# %%
# Specify categorical columns for one-hot encoding
categorical_cols = ['TransactionType', 'Location', 'Channel', 'CustomerOccupation']

# Apply one-hot encoding only to categorical columns
data_encoded = pd.get_dummies(data, columns=categorical_cols, drop_first=True)

# %%
data_encoded.head()
# Out:
#      TransactionID AccountID  TransactionAmount     TransactionDate  \
# 1312      TX001313   AC00001              47.79 2023-09-15 17:00:20
# 2016      TX002017   AC00001             212.97 2023-11-14 16:56:34
# 2120      TX002121   AC00002             476.99 2023-01-10 16:00:32
# 20        TX000021   AC00002              59.32 2023-02-28 16:36:58
# 1476      TX001477   AC00002              12.62 2023-05-05 16:35:44
#
#       CustomerAge  TransactionDuration  LoginAttempts  AccountBalance  \
# 1312           25                   37              1         1649.92
# 2016           59                  178              1         4180.40
# 2120           23                  187              1         1154.48
# 20             71                   38              1         5750.89
# 1476           33                   61              1         6420.47
#
#      PreviousTransactionDate  TransactionFrequency  ...  Location_San Jose  \
# 1312     2024-11-04 08:11:55                     2  ...              False
# 2016     2024-11-04 08:10:42                     2  ...              False
# 2120     2024-11-04 08:10:10                     7  ...              False
# 20       2024-11-04 08:09:24                     7  ...              False
# 1476     2024-11-04 08:09:03                     7  ...              False
#
#       Location_Seattle  Location_Tucson  Location_Virginia Beach  \
# 1312             False            False                    False
# 2016             False            False                    False
# 2120             False            False                    False
# 20               False            False                    False
# 1476             False            False                    False
#
#       Location_Washington  Channel_Branch  Channel_Online  \
# 1312                False            True           False
# 2016                False           False            True
# 2120                False           False            True
# 20                  False            True           False
# 1476                False            True           False
#
#       CustomerOccupation_Engineer  CustomerOccupation_Retired  \
# 1312                        False                       False
# 2016                         True                       False
# 2120                        False                       False
# 20                          False                        True
# 1476                        False                       False
#
#       CustomerOccupation_Student
# 1312                        True
# 2016                       False
# 2120                        True
# 20                         False
# 1476                       False
#
# [5 rows x 62 columns]

# %%
# Select numerical columns
num_cols = ['TransactionAmount', 'AccountBalance', 'TransactionDuration', 'CustomerAge','TransactionFrequency', 'TransactionHour', 
            'TransactionDay', 'TransactionMonth', 'TransactionTimeDiff']

# Initialize the scaler
scaler = RobustScaler()

# Apply scaling
data_encoded[num_cols] = scaler.fit_transform(data_encoded[num_cols])

# %%
data_encoded.head()
# Out:
#      TransactionID AccountID  TransactionAmount     TransactionDate  \
# 1312      TX001313   AC00001          -0.491068 2023-09-15 17:00:20
# 2016      TX002017   AC00001           0.005501 2023-11-14 16:56:34
# 2120      TX002121   AC00002           0.799206 2023-01-10 16:00:32
# 20        TX000021   AC00002          -0.456406 2023-02-28 16:36:58
# 1476      TX001477   AC00002          -0.596797 2023-05-05 16:35:44
#
#       CustomerAge  TransactionDuration  LoginAttempts  AccountBalance  \
# 1312      -0.6250            -0.770408              1       -0.499735
# 2016       0.4375             0.668367              1       -0.089904
# 2120      -0.6875             0.760204              1       -0.579976
# 20         0.8125            -0.760204              1        0.164449
# 1476      -0.3750            -0.525510              1        0.272892
#
#      PreviousTransactionDate  TransactionFrequency  ...  Location_San Jose  \
# 1312     2024-11-04 08:11:55             -1.333333  ...              False
# 2016     2024-11-04 08:10:42             -1.333333  ...              False
# 2120     2024-11-04 08:10:10              0.333333  ...              False
# 20       2024-11-04 08:09:24              0.333333  ...              False
# 1476     2024-11-04 08:09:03              0.333333  ...              False
#
#       Location_Seattle  Location_Tucson  Location_Virginia Beach  \
# 1312             False            False                    False
# 2016             False            False                    False
# 2120             False            False                    False
# 20               False            False                    False
# 1476             False            False                    False
#
#       Location_Washington  Channel_Branch  Channel_Online  \
# 1312                False            True           False
# 2016                False           False            True
# 2120                False           False            True
# 20                  False            True           False
# 1476                False            True           False
#
#       CustomerOccupation_Engineer  CustomerOccupation_Retired  \
# 1312                        False                       False
# 2016                         True                       False
# 2120                        False                       False
# 20                          False                        True
# 1476                        False                       False
#
#       CustomerOccupation_Student
# 1312                        True
# 2016                       False
# 2120                        True
# 20                         False
# 1476                       False
#
# [5 rows x 62 columns]

# %%
data_encoded.columns
# Out:
# Index(['TransactionID', 'AccountID', 'TransactionAmount', 'TransactionDate',
#        'CustomerAge', 'TransactionDuration', 'LoginAttempts', 'AccountBalance',
#        'PreviousTransactionDate', 'TransactionFrequency', 'TransactionHour',
#        'TransactionDay', 'TransactionMonth', 'TransactionTimeDiff',
#        'TransactionType_Debit', 'Location_Atlanta', 'Location_Austin',
#        'Location_Baltimore', 'Location_Boston', 'Location_Charlotte',
#        'Location_Chicago', 'Location_Colorado Springs', 'Location_Columbus',
#        'Location_Dallas', 'Location_Denver', 'Location_Detroit',
#        'Location_El Paso', 'Location_Fort Worth', 'Location_Fresno',
#        'Location_Houston', 'Location_Indianapolis', 'Location_Jacksonville',
#        'Location_Kansas City', 'Location_Las Vegas', 'Location_Los Angeles',
#        'Location_Louisville', 'Location_Memphis', 'Location_Mesa',
#        'Location_Miami', 'Location_Milwaukee', 'Location_Nashville',
#        'Location_New York', 'Location_Oklahoma City', 'Location_Omaha',
#        'Location_Philadelphia', 'Location_Phoenix', 'Location_Portland',
#        'Location_Raleigh', 'Location_Sacramento', 'Location_San Antonio',
#        'Location_San Diego', 'Location_San Francisco', 'Location_San Jose',
#        'Location_Seattle', 'Location_Tucson', 'Location_Virginia Beach',
#        'Location_Washington', 'Channel_Branch', 'Channel_Online',
#        'CustomerOccupation_Engineer', 'CustomerOccupation_Retired',
#        'CustomerOccupation_Student'],
#       dtype='object')

# %%
data_preprocessed = data_encoded.copy()
data_preprocessed = data_preprocessed.drop(['TransactionID','AccountID','TransactionDate','PreviousTransactionDate'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test =  train_test_split(data_preprocessed,test_size=0.2,random_state=35) #Assuming only 1% transactions are fraudulent

# %%
X_train.head()
# Out:
#       TransactionAmount  CustomerAge  TransactionDuration  LoginAttempts  \
# 1039           1.095711     -0.06250             0.168367              1
# 2500           0.344093      0.75000            -0.250000              1
# 1863          -0.323651     -0.40625            -0.811224              1
# 1025          -0.330084     -0.65625            -0.678571              1
# 1151           0.683767     -0.25000            -0.096939              1
#
#       AccountBalance  TransactionFrequency  TransactionHour  TransactionDay  \
# 1039       -0.728988              0.666667              2.0         -0.2500
# 2500        1.464356             -1.000000              0.0          0.6250
# 1863        0.284842             -0.333333              0.0          0.8750
# 1025       -0.653054             -1.333333              1.0         -0.8125
# 1151        0.689759             -0.666667              1.0          0.8750
#
#       TransactionMonth  TransactionTimeDiff  ...  Location_San Jose  \
# 1039         -0.142857            -0.442270  ...              False
# 2500          0.285714             1.345268  ...              False
# 1863         -0.857143            -0.443199  ...              False
# 1025         -0.571429            -0.443199  ...              False
# 1151          0.428571             0.935376  ...               True
#
#       Location_Seattle  Location_Tucson  Location_Virginia Beach  \
# 1039             False            False                    False
# 2500             False            False                    False
# 1863             False            False                    False
# 1025             False            False                    False
# 1151             False            False                    False
#
#       Location_Washington  Channel_Branch  Channel_Online  \
# 1039                False           False            True
# 2500                False           False           False
# 1863                False           False           False
# 1025                False           False           False
# 1151                False           False            True
#
#       CustomerOccupation_Engineer  CustomerOccupation_Retired  \
# 1039                        False                       False
# 2500                        False                       False
# 1863                         True                       False
# 1025                        False                       False
# 1151                         True                       False
#
#       CustomerOccupation_Student
# 1039                       False
# 2500                       False
# 1863                       False
# 1025                        True
# 1151                       False
#
# [5 rows x 58 columns]

# %%
X_test.head()
# Out:
#       TransactionAmount  CustomerAge  TransactionDuration  LoginAttempts  \
# 758            0.077170     -0.71875            -0.994898              1
# 2383           0.361469     -0.09375             0.096939              1
# 1916          -0.354735      0.68750             0.392857              1
# 1908           0.852326     -0.37500            -0.025510              1
# 52            -0.377913      0.68750             0.331633              1
#
#       AccountBalance  TransactionFrequency  TransactionHour  TransactionDay  \
# 758        -0.635171             -0.333333              0.0          0.6250
# 2383       -0.630171             -1.000000              1.0          0.8750
# 1916        0.119575              1.000000              0.0         -0.8750
# 1908        0.128986              1.666667              0.0          0.1875
# 52          1.647011             -1.000000              0.0         -0.5625
#
#       TransactionMonth  TransactionTimeDiff  ...  Location_San Jose  \
# 758           0.428571             0.525031  ...              False
# 2383         -0.285714             0.607164  ...              False
# 1916         -0.857143            -0.443199  ...              False
# 1908         -0.142857             0.590837  ...              False
# 52           -0.142857             1.770553  ...              False
#
#       Location_Seattle  Location_Tucson  Location_Virginia Beach  \
# 758              False            False                    False
# 2383             False            False                    False
# 1916             False            False                    False
# 1908             False            False                    False
# 52               False            False                     True
#
#       Location_Washington  Channel_Branch  Channel_Online  \
# 758                 False            True           False
# 2383                False           False           False
# 1916                False           False            True
# 1908                False           False            True
# 52                  False            True           False
#
#       CustomerOccupation_Engineer  CustomerOccupation_Retired  \
# 758                         False                       False
# 2383                         True                       False
# 1916                        False                        True
# 1908                        False                       False
# 52                          False                       False
#
#       CustomerOccupation_Student
# 758                         True
# 2383                       False
# 1916                       False
# 1908                       False
# 52                         False
#
# [5 rows x 58 columns]

# %%
from sklearn.ensemble import IsolationForest

# %%
from sklearn.decomposition import PCA


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_test)

# %%
model = IsolationForest(n_estimators=400,contamination=0.03, max_samples='auto', 
    max_features=1.0,random_state=35)
model.fit(X_pca)
# Out:
# IsolationForest(contamination=0.03, n_estimators=400, random_state=35)

# %%
scores = model.decision_function(X_pca)
plt.hist(scores, bins=50)
plt.title("Anomaly Score Distribution")
plt.show()

# %%
X_pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])

# Add predictions as a new column
X_pca_df['Anomaly'] = predictions

# Filter for anomalies
anomalies = X_pca_df[X_pca_df['Anomaly'] == -1]

print("Number of Anomalies Detected:", len(anomalies))
# Out:
# Number of Anomalies Detected: 16

# %%
num_anomalies = sum(predictions == -1)
total = len(predictions)
print(f"Anomaly proportion: {num_anomalies / total:.2%}")
# Out:
# Anomaly proportion: 3.18%

# %%
plt.scatter(X_pca[predictions == 1, 0], X_pca[predictions == 1, 1], c='blue', label='Normal', alpha=0.5)
plt.scatter(X_pca[predictions == -1, 0], X_pca[predictions == -1, 1], c='red', label='Anomaly', alpha=0.5)
plt.legend()
plt.title("PCA of Transactions")
plt.show()

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(X_pca, predictions)
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.6000151725715411
